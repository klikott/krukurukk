# %% [markdown]
# <a href="https://colab.research.google.com/github/klikott/krukurukk/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = "/content/bovespa_indexes.csv"

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#             Date Symbol     Adj Close         Close          High  \
# 0     2010-01-04  ^BVSP  70045.000000  70045.000000  70081.000000
# 1     2010-01-05  ^BVSP  70240.000000  70240.000000  70595.000000
# 2     2010-01-06  ^BVSP  70729.000000  70729.000000  70937.000000
# 3     2010-01-07  ^BVSP  70451.000000  70451.000000  70723.000000
# 4     2010-01-08  ^BVSP  70263.000000  70263.000000  70766.000000
# ...          ...    ...           ...           ...           ...
# 9065  2024-03-01   IBRA   5100.669922   5100.669922   5122.020020
# 9066  2024-03-01   MLCX   2583.790039   2583.790039   2595.540039
# 9067  2024-03-01   BDRX  15725.209961  15725.209961  15732.179688
# 9068  2024-03-01   ISEE   3658.530029   3658.530029   3666.709961
# 9069  2024-03-01   IGNM   3814.870117   3814.870117   3823.969971
#
#                Low          Open     Volume
# 0     68587.000000  68587.000000  1655400.0
# 1     69928.000000  70046.000000  1984200.0
# ...

# %%
data.head()
# Out:
#          Date Symbol  Adj Close    Close     High      Low     Open     Volume
# 0  2010-01-04  ^BVSP    70045.0  70045.0  70081.0  68587.0  68587.0  1655400.0
# 1  2010-01-05  ^BVSP    70240.0  70240.0  70595.0  69928.0  70046.0  1984200.0
# 2  2010-01-06  ^BVSP    70729.0  70729.0  70937.0  70016.0  70237.0  2243600.0
# 3  2010-01-07  ^BVSP    70451.0  70451.0  70723.0  70045.0  70723.0  1555000.0
# 4  2010-01-08  ^BVSP    70263.0  70263.0  70766.0  70158.0  70455.0  1634400.0

# %%
print(data.dtypes)
# Out:
# Date          object
# Symbol        object
# Adj Close    float64
# Close        float64
# High         float64
# Low          float64
# Open         float64
# Volume       float64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#             Date Symbol     Adj Close         Close           Low  \
# 0     2010-01-04  ^BVSP  70045.000000  70045.000000  68587.000000
# 1     2010-01-05  ^BVSP  70240.000000  70240.000000  69928.000000
# 2     2010-01-06  ^BVSP  70729.000000  70729.000000  70016.000000
# 3     2010-01-07  ^BVSP  70451.000000  70451.000000  70045.000000
# 4     2010-01-08  ^BVSP  70263.000000  70263.000000  70158.000000
# ...          ...    ...           ...           ...           ...
# 9065  2024-03-01   IBRA   5100.669922   5100.669922   5082.410156
# 9066  2024-03-01   MLCX   2583.790039   2583.790039   2576.179932
# 9067  2024-03-01   BDRX  15725.209961  15725.209961  15451.280273
# 9068  2024-03-01   ISEE   3658.530029   3658.530029   3631.409912
# 9069  2024-03-01   IGNM   3814.870117   3814.870117   3792.149902
#
#               Open     Volume
# 0     68587.000000  1655400.0
# 1     70046.000000  1984200.0
# 2     70237.000000  2243600.0
# 3     70723.000000  1555000.0
# ...

# %%
data.describe()
# Out:
#            Adj Close          Close           High            Low  \
# count    9070.000000    9070.000000    9070.000000    9070.000000
# mean    37819.876320   37819.876320   38164.353581   37461.921049
# std     36027.173433   36027.173433   36335.580498   35703.673160
# min       938.080017     938.080017     939.289978     922.700012
# 25%     10243.897461   10243.897461   10367.314697   10151.794678
# 50%     16865.910156   16865.910156   16991.300781   16706.685547
# 75%     61087.750000   61087.750000   61656.750000   60562.750000
# max    134194.000000  134194.000000  134392.000000  133832.000000
#
#                 Open        Volume
# count    9070.000000  9.070000e+03
# mean    37812.124737  2.192303e+06
# std     36018.319557  3.742413e+06
# min       936.880005  0.000000e+00
# 25%     10242.984863  0.000000e+00
# 50%     16858.389648  0.000000e+00
# 75%     61105.250000  3.299875e+06
# max    134194.000000  2.602930e+07

# %%
data.loc[:,"Close":].corr()
# Out:
#            Close      High       Low      Open    Volume
# Close   1.000000  0.999906  0.999927  0.999786  0.863972
# High    0.999906  1.000000  0.999879  0.999913  0.865395
# Low     0.999927  0.999879  1.000000  0.999870  0.862500
# Open    0.999786  0.999913  0.999870  1.000000  0.863899
# Volume  0.863972  0.865395  0.862500  0.863899  1.000000

# %%
# @title High vs Low

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='High', y='Low', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-c3e376db-6eaa-4379-8591-5c7ff164d486" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3e376db-6eaa-4379-8591-5c7ff164d486">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Brazilian Stock Market"
# Out:
# ...
# ref                                                               title                                                 size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  --------------------------------------------------  ------  -------------------  -------------  ---------  ---------------
# andrewmvd/brazilian-stock-market                                  Brazilian Stock Market (daily updated)                17MB  2024-03-03 06:57:47            811         67  1.0
# fernandojvdasilva/stock-tweets-ptbr-emotions                      Brazilian Stock Market Tweets with Emotions         1016KB  2018-05-09 17:55:28            554         18  0.7941176
# gbonesso/b3-stock-quotes                                          Brazilian Stock Quotes                               584MB  2020-04-22 15:35:13            814         30  0.7058824
# ...

# %%
# !kaggle datasets download andrewmvd/brazilian-stock-market
# Out:
# ...
#  70% 12.0M/17.1M [00:00<00:00, 55.3MB/s]
# 100% 17.1M/17.1M [00:00<00:00, 72.5MB/s]

# %%
# !unzip /content/brazilian-stock-market.zip
# Out:
# Archive:  /content/brazilian-stock-market.zip
#   inflating: bovespa_indexes.csv
#   inflating: bovespa_stocks.csv
#   inflating: economic_indicators.csv

# %%
pd.read_csv('/content/bovespa_indexes.csv')
# Out:
#             Date Symbol     Adj Close         Close          High  \
# 0     2010-01-04  ^BVSP  70045.000000  70045.000000  70081.000000
# 1     2010-01-05  ^BVSP  70240.000000  70240.000000  70595.000000
# 2     2010-01-06  ^BVSP  70729.000000  70729.000000  70937.000000
# 3     2010-01-07  ^BVSP  70451.000000  70451.000000  70723.000000
# 4     2010-01-08  ^BVSP  70263.000000  70263.000000  70766.000000
# ...          ...    ...           ...           ...           ...
# 9065  2024-03-01   IBRA   5100.669922   5100.669922   5122.020020
# 9066  2024-03-01   MLCX   2583.790039   2583.790039   2595.540039
# 9067  2024-03-01   BDRX  15725.209961  15725.209961  15732.179688
# 9068  2024-03-01   ISEE   3658.530029   3658.530029   3666.709961
# 9069  2024-03-01   IGNM   3814.870117   3814.870117   3823.969971
#
#                Low          Open     Volume
# 0     68587.000000  68587.000000  1655400.0
# 1     69928.000000  70046.000000  1984200.0
# ...
